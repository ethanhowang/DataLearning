# %% [markdown]
# # Week of 5/2 to 5/8

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot([1, 2, 3, 4, 5], [2, 4, 6, 8, 10])
plt.ylabel('y')
plt.xlabel('x')
plt.title('Plotting example')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# !pip install xlrd

# %%
spreadsht = pd.ExcelFile('ImmigrationData.xlsx')
print(spreadsht.sheet_names)
df_imm = pd.read_excel('ImmigrationData.xlsx', skiprows=20, sheet_name=None)
df_imm.get("Canada by Citizenship")
# Out:
# ['Regions by Citizenship', 'Canada by Citizenship', 'Canada by Citizenship (2)']
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
# 195  Immigrants  Foreigners         Unknown   999    World   999
# 196  Immigrants        Both           Total   999    World   999
#
#              RegName  DEV             DevName    1980  ...    2004    2005  \
# ...
