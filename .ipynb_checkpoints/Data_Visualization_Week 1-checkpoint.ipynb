# %% [markdown]
# # Week of 5/2 to 5/8

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot([1, 2, 3, 4, 5], [2, 4, 6, 8, 10])
plt.ylabel('y')
plt.xlabel('x')
plt.title('Plotting example')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# !pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\ethan\anaconda3\lib\site-packages (1.2.0)

# %%
spreadsht = pd.ExcelFile('ImmigrationData.xlsx')
spreadsht.sheet_names
df_imm = pd.read_excel('ImmigrationData.xlsx', skiprows=20)
df_imm.iloc[0]
# Out:
# Type              Immigrants
# Coverage            Citizens
# AreaName    Northern America
# RegName     Northern America
# 1980                      ..
# 1981                      ..
# 1982                      ..
# 1983                      ..
# 1984                      ..
# 1985                      ..
# 1986                      ..
# 1987                      ..
# 1988                      ..
# 1989                      ..
# 1990                       3
# 1991                       3
# 1992                       4
# 1993                       3
# 1994                       1
# 1995                       1
# 1996                       1
# 1997                      ..
# 1998                      ..
# 1999                      ..
# 2000                      ..
# 2001                      ..
# 2002                      ..
# 2003                      ..
# 2004                      ..
# 2005                      ..
# 2006                      ..
# 2007                      ..
# 2008                      ..
# 2009                      ..
# 2010                      ..
# 2011                       1
# 2012                       1
# 2013                     NaN
# Name: 0, dtype: object
